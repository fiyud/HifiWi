# %%
# %cd D:/NCKH.2025-2026/VinWifi/DT-Pose
# Out:
# [WinError 2] The system cannot find the file specified: 'D:/NCKH.2025-2026/VinWifi/DT-Pose'
# d:\NCKH.2025-2026\VinWifi\HifiWi

# %%
# !python process.py
# Out:
# Traceback (most recent call last):
#   File "D:\NCKH.2025-2026\VinWifi\DT-Pose\data\wipose\process.py", line 100, in <module>
#     main()
#   File "D:\NCKH.2025-2026\VinWifi\DT-Pose\data\wipose\process.py", line 76, in main
#     name_list = load_file_name_list(setting_path)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\NCKH.2025-2026\VinWifi\DT-Pose\data\wipose\process.py", line 13, in load_file_name_list
#     with open(file_path, 'r') as file_to_read:
#          ^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'Train_data_list.txt'

# %%
# !python train_pose.py --config_file config/wipose/pose_config.yaml
